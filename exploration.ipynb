# %%
import pandas as pd

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_colwidth', None)

# %%
events_path = '/Users/Zechariah/Documents/codeRepo/deCohort/project3/extended_list.csv'
eventsMentions_path = '/Users/Zechariah/Documents/codeRepo/deCohort/project3/eventsMentions.xlsx'

# %%
df_events = pd.read_csv(events_path)
df_mentions = pd.read_excel(eventsMentions_path)

# %% [markdown]
# # Events Exploration

# %%
pd.set_option('display.max_columns', None)
df_events.head()
# Out:
#    GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 0      431084813  20150506     201505  2015     2015.3452  MLTGOVELI
# 1      444802691  20150629     201506  2015     2015.4904  INDGOVENV
# 2      415903079  20150310     201503  2015     2015.1918        MDV
# 3      477542595  20151019     201510  2015     2015.7918        JUD
# 4      441597924  20150617     201506  2015     2015.4575        MDV
#
#        Actor1Name Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  \
# 0  LAWRENCE GONZI               MLT                  NaN              NaN
# 1   JAIRAM RAMESH               IND                  NaN              NaN
# 2            MALE               MDV                  NaN              NaN
# 3           JUDGE               NaN                  NaN              NaN
# 4            MALE               MDV                  NaN              NaN
#
#   Actor1Religion1Code Actor1Religion2Code Actor1Type1Code Actor2Code  \
# ...

# %%
df_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2706 entries, 0 to 2705
# Data columns (total 57 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GLOBALEVENTID          2706 non-null   int64
#  1   SQLDATE                2706 non-null   int64
#  2   MonthYear              2706 non-null   int64
#  3   Year                   2706 non-null   int64
#  4   FractionDate           2706 non-null   float64
#  5   Actor1Code             2468 non-null   object
#  6   Actor1Name             2468 non-null   object
#  7   Actor1CountryCode      1485 non-null   object
#  8   Actor1KnownGroupCode   46 non-null     object
#  9   Actor1EthnicCode       35 non-null     object
#  10  Actor1Religion1Code    48 non-null     object
#  11  Actor1Religion2Code    9 non-null      object
#  12  Actor1Type1Code        1258 non-null   object
#  13  Actor2Code             1981 non-null   object
# ...

# %%
df_events = df_events[['GLOBALEVENTID', 'SQLDATE', 'MonthYear', 'Year',
       'FractionDate', 'Actor1Code', 'Actor1Name', 'Actor1CountryCode',
       'Actor1KnownGroupCode', 'Actor1EthnicCode', 'Actor1Religion1Code',
       'Actor1Religion2Code', 'Actor1Type1Code', 'Actor2Code', 'Actor2Name', 'Actor2CountryCode',
       'Actor2KnownGroupCode', 'Actor2EthnicCode', 'Actor2Religion1Code',
       'Actor2Religion2Code', 'Actor2Type1Code', 'IsRootEvent', 'EventCode', 'EventBaseCode',
       'EventRootCode', 'QuadClass', 'GoldsteinScale', 'NumMentions',
       'NumSources', 'NumArticles', 'AvgTone', 'Actor1Geo_Type',
       'Actor1Geo_FullName', 'Actor1Geo_CountryCode', 'Actor1Geo_ADM1Code',
       'Actor1Geo_ADM2Code', 'Actor1Geo_Lat', 'Actor1Geo_Long',
       'Actor1Geo_FeatureID', 'Actor2Geo_Type', 'Actor2Geo_FullName',
       'Actor2Geo_CountryCode', 'Actor2Geo_ADM1Code', 'Actor2Geo_ADM2Code',
       'Actor2Geo_Lat', 'Actor2Geo_Long', 'Actor2Geo_FeatureID',
       'ActionGeo_Type', 'ActionGeo_FullName', 'ActionGeo_CountryCode',
       'ActionGeo_ADM1Code', 'ActionGeo_ADM2Code', 'ActionGeo_Lat',
       'ActionGeo_Long', 'ActionGeo_FeatureID', 'DATEADDED', 'SOURCEURL']]

# %%
df_actor = df_events[['GLOBALEVENTID', 'SQLDATE', 'MonthYear', 'Year',
       'FractionDate', 'Actor1Code', 'Actor1Name', 'Actor1CountryCode',
       'Actor1KnownGroupCode', 'Actor1EthnicCode', 'Actor1Religion1Code',
       'Actor1Religion2Code', 'Actor1Type1Code', 'Actor2Code', 'Actor2Name', 'Actor2CountryCode',
       'Actor2KnownGroupCode', 'Actor2EthnicCode', 'Actor2Religion1Code',
       'Actor2Religion2Code', 'Actor2Type1Code', 'Actor1Geo_Type',
       'Actor1Geo_FullName', 'Actor1Geo_CountryCode', 'Actor1Geo_ADM1Code',
       'Actor1Geo_ADM2Code', 'Actor1Geo_Lat', 'Actor1Geo_Long',
       'Actor1Geo_FeatureID', 'Actor2Geo_Type', 'Actor2Geo_FullName',
       'Actor2Geo_CountryCode', 'Actor2Geo_ADM1Code', 'Actor2Geo_ADM2Code',
       'Actor2Geo_Lat', 'Actor2Geo_Long', 'Actor2Geo_FeatureID','DATEADDED', 'SOURCEURL']]

# %%
df_event = df_events[['GLOBALEVENTID', 'SQLDATE', 'MonthYear', 'Year',
       'IsRootEvent', 'EventCode', 'EventBaseCode',
       'EventRootCode', 'QuadClass', 'GoldsteinScale', 'NumMentions',
       'NumSources', 'NumArticles', 'AvgTone','ActionGeo_Type', 
       'ActionGeo_FullName', 'ActionGeo_CountryCode',
       'ActionGeo_ADM1Code', 'ActionGeo_ADM2Code', 'ActionGeo_Lat',
       'ActionGeo_Long', 'ActionGeo_FeatureID', 'DATEADDED', 'SOURCEURL']]

# %%
df_event.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2706 entries, 0 to 2705
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GLOBALEVENTID          2706 non-null   int64
#  1   SQLDATE                2706 non-null   int64
#  2   MonthYear              2706 non-null   int64
#  3   Year                   2706 non-null   int64
#  4   IsRootEvent            2706 non-null   int64
#  5   EventCode              2706 non-null   int64
#  6   EventBaseCode          2706 non-null   int64
#  7   EventRootCode          2706 non-null   int64
#  8   QuadClass              2706 non-null   int64
#  9   GoldsteinScale         2706 non-null   float64
#  10  NumMentions            2706 non-null   int64
#  11  NumSources             2706 non-null   int64
#  12  NumArticles            2706 non-null   int64
#  13  AvgTone                2706 non-null   float64
# ...

# %%
x = df_event.groupby('GoldsteinScale')

# %%
pd.set_option('display.max_columns', None)
x.get_group(1.0).head()
# Out:
#     GLOBALEVENTID   SQLDATE  MonthYear  Year  IsRootEvent  EventCode  \
# 1       444802691  20150629     201506  2015            1         40
# 10      422149400  20150402     201504  2015            1         40
# 14      451360974  20150722     201507  2015            1         40
# 64      519389887  20160309     201603  2016            1         40
# 76      454209110  20150801     201508  2015            1         41
#
#     EventBaseCode  EventRootCode  QuadClass  GoldsteinScale  NumMentions  \
# 1              40              4          1             1.0            5
# 10             40              4          1             1.0           10
# 14             40              4          1             1.0           30
# 64             40              4          1             1.0            5
# 76             41              4          1             1.0           10
#
#     NumSources  NumArticles   AvgTone  ActionGeo_Type ActionGeo_FullName  \
# ...

# %%
df_events['Actor1Type1Code'].value_counts()
# Out:
# Actor1Type1Code
# GOV    287
# EDU    107
# COP     99
# LEG     98
# BUS     89
# JUD     89
# CVL     88
# MIL     74
# IGO     48
# MED     48
# MNC     41
# LAB     34
# REB     29
# CRM     25
# UAF     18
# HLH     17
# OPP     14
# ELI     14
# NGO     11
# AGR      8
# REF      4
# ENV      4
# SEP      3
# SET      3
# INT      2
# SPY      1
# IMG      1
# RAD      1
# UIS      1
# Name: count, dtype: int64

# %%
df_events['EventCode'].value_counts()
# Out:
# EventCode
# 10      202
# 51      193
# 42      188
# 43      174
# 20      158
#        ...
# 1121      1
# 1822      1
# 171       1
# 1031      1
# 56        1
# Name: count, Length: 123, dtype: int64

# %% [markdown]
# # Mentions Exploration

# %%
headers = df_mentions.iloc[0].values
df_mentions.columns = headers
df_mentions.drop(index=0, axis=0, inplace=True)

# %%
df_mentions.head()
# Out:
#   GLOBALEVENTID   EventTimeDate MentionTimeDate MentionType MentionSourceName  \
# 1     509185559  20160206084500  20160206084500           1      pchrgaza.org
# 2     547841434  20160607004500  20160607033000           1            fax.al
# 3     464838680  20150908124500  20150908230000           1          kdwn.com
# 4     669272588  20170630071500  20170630093000           1            fax.al
# 5     677142787  20170730070000  20170730081500           1            fax.al
#
#                                    MentionIdentifier SentenceID  \
# 1                     http://pchrgaza.org/en/?p=4015        256
# 2  http://fax.al/news/4090763/ja-si-u-pasqyrua-vi...        256
# 3  http://kdwn.com/2015/09/08/the-latest-israel-b...        256
# 4  http://fax.al/news/10607290/lr-pdsh-misioni-i-...        256
# 5  http://fax.al/news/11016507/pdk-se-i-kerkohet-...        256
#
#   Actor1CharOffset Actor2CharOffset ActionCharOffset InRawText Confidence  \
# ...

# %%
df_mentions.info()

# %%
merge = pd.merge(df_events,df_mentions,on='GLOBALEVENTID',how='left')

# %% [markdown]
# ## Why does data get lost after merge? (Datatype problem?)

# %%
merge.head()
# Out:
#   GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 0     431084813  20150506     201505  2015     2015.3452  MLTGOVELI
# 1     444802691  20150629     201506  2015     2015.4904  INDGOVENV
# 2     415903079  20150310     201503  2015     2015.1918        MDV
# 3     477542595  20151019     201510  2015     2015.7918        JUD
# 4     441597924  20150617     201506  2015     2015.4575        MDV
#
#        Actor1Name Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  \
# 0  LAWRENCE GONZI               MLT                  NaN              NaN
# 1   JAIRAM RAMESH               IND                  NaN              NaN
# 2            MALE               MDV                  NaN              NaN
# 3           JUDGE               NaN                  NaN              NaN
# 4            MALE               MDV                  NaN              NaN
#
#   Actor1Religion1Code Actor1Religion2Code Actor1Type1Code Actor2Code  \
# ...

# %% [markdown]
# ## What are we looking for below? Why column named 'Unnamed: 1'

# %%
df_mentions['Unnamed: 1'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Zechariah\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
